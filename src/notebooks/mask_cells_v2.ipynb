# %% [markdown]
# # Prétraitement des images en appliquant un masque autour des cellules

# %%
import os
import glob
import random
import ipywidgets as widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import pandas as pd
import cv2
import numpy as np

# %%
# --- Configuration ---
# Chemin vers le répertoire contenant les dossiers des types de cellules
data_path = "/home/anthony-sauvage/repo/BloodCellClassification/src/data/raw/bloodcells_dataset"
def get_image_path(dataset_map, subdir_name: str, index_img: int):
    list_img = dataset_map[subdir_name]
    img_path = os.path.join(data_path, f"{subdir_name}/{list_img[index_img]}")
    #print(img_path)
    return img_path

def map_subdirs_to_files(dir_path):
    """
    Crée un dictionnaire qui mappe directement chaque nom de sous-répertoire
    à la liste de ses fichiers (images).

    Format de sortie :
    {
        "nom_sous_repertoire_1": ["img1.jpg", "img2.jpg"],
        "nom_sous_repertoire_2": ["imgA.jpg", "imgB.jpg"],
        ...
    }

    Args:
        dir_path (str): Le chemin vers le répertoire principal.

    Returns:
        dict: Un dictionnaire où les clés sont les noms des sous-répertoires
              et les valeurs sont les listes de noms de fichiers.
              Retourne un dictionnaire vide si le chemin n'est pas un répertoire valide ou est vide.
    """
    direct_mapping = {}
    if not os.path.isdir(dir_path):
        print(f"Le chemin '{dir_path}' n'est pas un répertoire valide.")
        return direct_mapping

    for item_name in os.listdir(dir_path):
        item_path = os.path.join(dir_path, item_name)
        
        # On s'assure que c'est bien un sous-répertoire
        if os.path.isdir(item_path):
            # Liste uniquement les fichiers dans chaque sous-répertoire
            files_in_subdir = [f for f in os.listdir(item_path) if os.path.isfile(os.path.join(item_path, f))]
            direct_mapping[item_name] = files_in_subdir # Le nom du sous-répertoire est la clé
            
    return direct_mapping

dataset_map = map_subdirs_to_files(data_path)

# %% [markdown]
# # Chargement de l'image JPG

# %%
# Méthode 1: Avec OpenCV (recommandée)
def load_image_opencv(image_path):
    image = cv2.imread(image_path)  # Charge en BGR
    return image

# Méthode 2: Avec PIL/Pillow puis conversion
from PIL import Image
def load_image_pil(image_path):
    pil_image = Image.open(image_path)
    image = np.array(pil_image)
    # Convertir RGB vers BGR pour OpenCV
    if len(image.shape) == 3:
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image

# %% [markdown]
# # Cell mask

# %% [markdown]
# ## Approche par seuillage adaptatif
# Cette méthode exploite le fait que les cellules sont généralement plus sombres que le fond :

# %%
def create_adaptive_mask(image):
    # Conversion en niveaux de gris si nécessaire
    if len(image.shape) == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image
    
    # Seuillage adaptatif pour détecter les zones sombres
    binary = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                   cv2.THRESH_BINARY_INV, 15, 2)
    
    # Trouver les contours
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Sélectionner le contour le plus proche du centre
    center = (image.shape[1]//2, image.shape[0]//2)
    best_contour = min(contours, key=lambda c: cv2.pointPolygonTest(c, center, True)**2)
    
    # Créer le masque
    mask = np.zeros(gray.shape, dtype=np.uint8)
    cv2.fillPoly(mask, [best_contour], 255)
    
    return mask

# %% [markdown]
# # Approche par détection de cercles (pour les cellules rondes)
# ## Solution 1 : Agrandir le rayon détecté avec un facteur multiplicateur

# %%
def create_circle_mask_enlarged(image, enlargement_factor=1.3):
    """
    Crée un masque circulaire avec un rayon agrandi
    
    Args:
        image: image d'entrée
        enlargement_factor: facteur d'agrandissement du rayon (ex: 1.3 = +30%)
    """
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) if len(image.shape) == 3 else image
    
    # Détection de cercles avec des paramètres ajustés
    circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, dp=1, minDist=30,
                              param1=50, param2=30, minRadius=10, maxRadius=150)
    
    mask = np.zeros(gray.shape, dtype=np.uint8)
    
    if circles is not None:
        circles = np.round(circles[0, :]).astype("int")
        # Prendre le cercle le plus proche du centre
        center = (image.shape[1]//2, image.shape[0]//2)
        distances = [np.sqrt((x-center[0])**2 + (y-center[1])**2) for x, y, r in circles]
        best_circle = circles[np.argmin(distances)]
        
        # Agrandir le rayon
        enlarged_radius = int(best_circle[2] * enlargement_factor)
        
        cv2.circle(mask, (best_circle[0], best_circle[1]), enlarged_radius, 255, -1)
    
    return mask

# %% [markdown]
# ##  Solution 2 : Expansion morphologique du masque circulaire

# %%
def create_circle_mask_with_expansion(image, expansion_pixels=10):
    """
    Crée un masque circulaire puis l'expande avec des opérations morphologiques
    
    Args:
        image: image d'entrée
        expansion_pixels: nombre de pixels d'expansion
    """
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) if len(image.shape) == 3 else image
    
    circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, dp=1, minDist=30,
                              param1=50, param2=30, minRadius=10, maxRadius=150)
    
    mask = np.zeros(gray.shape, dtype=np.uint8)
    
    if circles is not None:
        circles = np.round(circles[0, :]).astype("int")
        center = (image.shape[1]//2, image.shape[0]//2)
        distances = [np.sqrt((x-center[0])**2 + (y-center[1])**2) for x, y, r in circles]
        best_circle = circles[np.argmin(distances)]
        
        cv2.circle(mask, (best_circle[0], best_circle[1]), best_circle[2], 255, -1)
        
        # Expansion morphologique
        kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, 
                                         (expansion_pixels*2+1, expansion_pixels*2+1))
        mask = cv2.dilate(mask, kernel, iterations=1)
    
    return mask

# %% [markdown]
# Détection automatique de la taille optimale

# %%
def create_adaptive_circle_mask(image):
    """
    Détecte automatiquement la taille optimale du cercle basée sur la cellule
    """
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) if len(image.shape) == 3 else image
    
    # D'abord, obtenir une estimation grossière avec le seuillage adaptatif
    adaptive_mask = create_adaptive_mask(image)
    
    if np.sum(adaptive_mask) == 0:
        return adaptive_mask
    
    # Trouver le contour principal
    contours, _ = cv2.findContours(adaptive_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        return adaptive_mask
    
    # Prendre le plus grand contour
    main_contour = max(contours, key=cv2.contourArea)
    
    # Calculer le cercle englobant minimal
    (x, y), radius = cv2.minEnclosingCircle(main_contour)
    center = (int(x), int(y))
    radius = int(radius * 1.2)  # Agrandir de 20%
    
    # Créer le masque circulaire optimisé
    mask = np.zeros(gray.shape, dtype=np.uint8)
    cv2.circle(mask, center, radius, 255, -1)
    
    return mask

# %% [markdown]
# ## Post-traitement
# Pour améliorer la qualité du masque :

# %%
def refine_mask(mask):
    # Opérations morphologiques pour nettoyer le masque
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    
    # Fermeture pour combler les trous
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    
    # Ouverture pour supprimer le bruit
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    
    # Remplissage des trous internes
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cv2.fillPoly(mask, contours, 255)
    
    return mask

# %% [markdown]
# # Pipeline pour créer des masques autour des cellules

# %%
def create_adaptive_mask(image):
    """
    image: array NumPy de forme (height, width, 3) pour une image couleur
           ou (height, width) pour une image en niveaux de gris
    """
    # Conversion en niveaux de gris si nécessaire
    if len(image.shape) == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image
    
    # Seuillage adaptatif pour détecter les zones sombres
    binary = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                   cv2.THRESH_BINARY_INV, 15, 2)
    
    # Trouver les contours
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    if not contours:
        return np.zeros(gray.shape, dtype=np.uint8)
    
    # Sélectionner le contour le plus proche du centre
    center = (image.shape[1]//2, image.shape[0]//2)
    best_contour = min(contours, key=lambda c: abs(cv2.pointPolygonTest(c, center, True)))
    
    # Créer le masque
    mask = np.zeros(gray.shape, dtype=np.uint8)
    cv2.fillPoly(mask, [best_contour], 255)
    
    return mask

def apply_mask_to_image(image, mask):
    """Applique le masque à l'image (met les pixels du fond à 0)"""
    if len(image.shape) == 3:
        # Image couleur
        masked_image = image.copy()
        masked_image[mask == 0] = [0, 0, 0]  # Fond noir
    else:
        # Image en niveaux de gris
        masked_image = image.copy()
        masked_image[mask == 0] = 0
    
    return masked_image

# Exemple d'utilisation complète
def process_cell_image(image_path):
    # 1. Charger l'image JPG
    image = cv2.imread(image_path)
    
    if image is None:
        print(f"Erreur: impossible de charger l'image {image_path}")
        return None
    
    # 2. Créer le masque
    # mask = create_adaptive_mask(image)
    # mask = create_circle_mask(image)
    #mask = create_robust_mask(image)
    mask = create_adaptive_circle_mask(image)
    #mask = refine_mask(mask)
    # 3. Appliquer le masque
    masked_image = apply_mask_to_image(image, mask)
    
    return masked_image, mask

# Utilisation
image_path = get_image_path(dataset_map, 'ig', index_img=0)
masked_image, mask = process_cell_image(image_path)

# Sauvegarder le résultat
if masked_image is not None:
    cv2.imwrite("mask/circle_cellule_masquee.jpg", masked_image)
    cv2.imwrite("mask/circle_masque.jpg", mask)

# %%
def display_before_after(image_path, figsize=(12, 6)):
    """
    Affiche l'image originale et l'image masquée côte à côte
    
    Args:
        image_path: chemin vers l'image JPG
        figsize: taille de la figure (largeur, hauteur)
    """
    # Traiter l'image
    masked_image, mask = process_cell_image(image_path)
    
    if masked_image is None:
        print(f"Erreur: impossible de traiter l'image {image_path}")
        return
    
    # Charger l'image originale
    original_image = cv2.imread(image_path)
    
    # Convertir BGR vers RGB pour matplotlib
    original_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
    masked_rgb = cv2.cvtColor(masked_image, cv2.COLOR_BGR2RGB)
    
    # Créer la figure avec 2 sous-graphiques
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    # Image originale
    axes[0].imshow(original_rgb)
    axes[0].set_title('Image Originale', fontsize=14)
    axes[0].axis('off')
    
    # Image masquée
    axes[1].imshow(masked_rgb)
    axes[1].set_title('Image Masquée', fontsize=14)
    axes[1].axis('off')
    
    # Ajuster l'espacement
    plt.tight_layout()
    plt.show()

image1_path = get_image_path(dataset_map, 'ig', index_img=10)    
display_before_after(image1_path, figsize=(12, 6))
image2_path = get_image_path(dataset_map, 'basophil', index_img=10)    
display_before_after(image2_path, figsize=(12, 6))

# %%
def display_before_after(image_path, figsize=(12, 6), output_dir=None):
    """
    Affiche l'image originale et l'image masquée côte à côte
    et sauvegarde l'image masquée dans le répertoire spécifié
    
    Args:
        image_path: chemin complet vers l'image JPG
        figsize: taille de la figure (largeur, hauteur)
        output_dir: nom du répertoire où sauvegarder l'image masquée
                   (sera créé à la racine du chemin de base s'il n'existe pas)
    """
    # Traiter l'image
    masked_image, mask = process_cell_image(image_path)
    
    if masked_image is None:
        print(f"Erreur: impossible de traiter l'image {image_path}")
        return
    
    # Charger l'image originale
    original_image = cv2.imread(image_path)
    
    # Convertir BGR vers RGB pour matplotlib
    original_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
    masked_rgb = cv2.cvtColor(masked_image, cv2.COLOR_BGR2RGB)
    
    # Sauvegarder l'image masquée si un répertoire de sortie est spécifié
    if output_dir is not None:
        # Définir le chemin de base
        base_path = "/home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset"
        
        # Créer le chemin complet du répertoire de sortie
        output_path = os.path.join(base_path, output_dir)
        
        # Créer le répertoire s'il n'existe pas
        os.makedirs(output_path, exist_ok=True)
        
        # Extraire le nom du fichier de l'image originale
        filename = os.path.basename(image_path)
        
        # Créer le chemin complet pour l'image masquée
        masked_image_path = os.path.join(output_path, f"masked_{filename}")
        
        # Sauvegarder l'image masquée
        cv2.imwrite(masked_image_path, masked_image)
        print(f"Image masquée sauvegardée dans: {masked_image_path}")
    
    # # Créer la figure avec 2 sous-graphiques
    # fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    # # Image originale
    # axes[0].imshow(original_rgb)
    # axes[0].set_title('Image Originale', fontsize=14)
    # axes[0].axis('off')
    
    # # Image masquée
    # axes[1].imshow(masked_rgb)
    # axes[1].set_title('Image Masquée', fontsize=14)
    # axes[1].axis('off')
    
    # # Ajuster l'espacement
    # plt.tight_layout()
    # plt.show()

# %%
dataset_map.keys()

# %%
for image_dir in dataset_map.keys():
    dir_path = os.path.join(data_path, image_dir)
    for image_file in os.listdir(dir_path):
        # Construire le chemin complet vers l'image
        full_image_path = os.path.join(dir_path, image_file)
        # Appeler la fonction avec le chemin complet
        display_before_after(full_image_path, figsize=(12, 6), output_dir=f"{image_dir}")
# Out:
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_614174.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_208869.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_441264.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_200759.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_756667.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_254469.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_119734.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_43964.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_258058.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_913537.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_279225.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_124214.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_822250.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_34131.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_669221.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_281882.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_932799.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_694130.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_646119.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_21766.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_191840.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_829851.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_104489.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_58512.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_829954.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_723180.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_345087.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_563857.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_789722.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_284535.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_927482.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_78013.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_281120.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_126743.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_942537.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_683175.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_902144.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_320924.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_742595.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_270476.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_778576.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_303285.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_548127.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_538551.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_504471.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_259829.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_310300.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_584605.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_64735.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_400397.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_40780.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_665750.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_934893.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_520409.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_408730.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_823874.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_160240.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_336475.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_361999.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_761664.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_611630.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_777779.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_685518.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_985489.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_542376.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_268194.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_927025.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_895852.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_15706.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_235322.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_807451.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_238612.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_450927.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_519576.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_124657.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_861380.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_440528.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_240351.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_474304.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_857918.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_888170.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_561879.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_503986.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_324323.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_412668.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_187417.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_451831.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_745693.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_637313.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_867860.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_343033.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_936059.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_821182.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_627607.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_375742.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_541271.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_302632.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_473364.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_89526.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_137898.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_512527.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_354013.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_601917.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_122393.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_248701.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_76778.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_560041.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_699128.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_16158080.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_632918.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_531368.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_609722.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_223639.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_414016.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_57525.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_582217.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_813728.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_620286.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_999873.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_835636.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_541239.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_331885.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_751785.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_396691.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_989204.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_38247.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_243551.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_654361.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_278393.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_768183.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_645860.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_972655.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_476965.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_113492.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_875743.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_336181.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_735881.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_914573.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_397113.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_815342.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_245496.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_590291.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_153442.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_988257.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_312339.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_694640.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_606427.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_208400.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_207099.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_894858.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_410839.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_40618.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_666302.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_345071.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_868050.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_748394.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_535754.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_645206.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_259133.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_512688.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_223777.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_121677.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_172256.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_724065.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_693987.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_432194.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_652010.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_954088.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_763220.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_580824.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_555614.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_762346.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_134910.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_822077.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_129854.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_583342.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_514745.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_962866.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_722432.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_785932.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_81658.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_601138.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_75396.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_326299.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_928768.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_210649.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_827830.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_422581.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_303333.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_334655.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_586846.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_615170.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_531457.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_234261.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_340981.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_785071.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_833896.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_499850.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_511652.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_800465.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_68662.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_64222.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_510782.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_397027.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_819129.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_244421.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_682327.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_197797.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_802552.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_787807.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_467686.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_76291.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_48172.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_402763.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_262428.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_371470.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_685398.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_749872.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_222334.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_514845.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_848060.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_248524.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_609783.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_535376.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_196144.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_581242.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_500446.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_208927.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_443545.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_406357.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_471265.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_624944.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_334225.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_403424.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_81064.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_977992.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_597.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_916480.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_908261.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_292758.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_633259.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_637239.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_716165.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_304195.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_386612.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_16146.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_359649.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_144537.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_548466.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_392462.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_227634.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_811554.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_124466.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_343011.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_889102.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_797628.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_162165.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_940150.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_114736.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_795936.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_310105.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_76114.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_14035.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_762344.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_871583.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_215565.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_680314.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_195258.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_92196.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_929039.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_929427.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_88731.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_525114.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_626927.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_775366.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_622915.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_859348.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_549884.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_963471.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_18496.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_189496.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_950123.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_380908.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_919469.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_430818.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_525564.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_403377.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_129331.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_468662.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_358860.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_814291.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_773144.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_630452.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_773103.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_108287.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_233570.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_674963.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_937332.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_779460.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_563535.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_645114.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_71976.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_967711.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_521039.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/platelet/masked_PLATELET_52796.jpg
# ...
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_642249.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_104431.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_512083.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_120253.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_745075.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_434045.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_722749.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_474241.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_154548.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_679758.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_71697.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_854393.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_269002.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_407150.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_100695.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_271075.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_634461.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_663123.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_258162.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_53920.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_372222.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_913613.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_855807.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_834548.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_345587.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_326040.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_803041.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_724779.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_858170.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_125756.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_551084.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_263017.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_948549.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_866623.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_860510.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_853016.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_532846.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_415531.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_478654.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_444171.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_183270.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_283783.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_194123.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_749513.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_473875.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_194646.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_369170.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_1524.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_873001.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_261626.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_762412.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_275440.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_952670.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_497693.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_468147.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_216731.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_493402.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_974962.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_619116.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_970300.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_771921.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_692135.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_290397.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_181047.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_163770.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_358712.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_489036.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_842653.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_676317.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_107817.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_120291.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_896245.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_723738.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_693501.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_406508.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_5979.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_991797.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_605192.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_581325.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_165898.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_29749.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_775809.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_132182.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_906623.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_645730.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_30883.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_763772.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_721856.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_469644.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_516349.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_70803.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_668866.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_767746.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_216299.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_62638.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_315312.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_801881.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_183392.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_771012.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_37784.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_900927.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_246145.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_36685.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_434289.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_759794.jpg
# Image masquée sauvegardée dans: /home/anthony-sauvage/repo/BloodCellClassification/src/data/processed/bloodcells_dataset/monocyte/masked_MO_377470.jpg

# %% [markdown]
# ## Pour traiter plusieurs images

# %%
import os
import glob

def process_multiple_images(input_folder, output_folder):
    # Créer le dossier de sortie s'il n'existe pas
    os.makedirs(output_folder, exist_ok=True)
    
    # Traiter tous les fichiers JPG
    for image_path in glob.glob(os.path.join(input_folder, "*.jpg")):
        filename = os.path.basename(image_path)
        name, ext = os.path.splitext(filename)
        
        # Traiter l'image
        masked_image, mask = process_cell_image(image_path)
        
        if masked_image is not None:
            # Sauvegarder l'image masquée
            output_path = os.path.join(output_folder, f"{name}_masked{ext}")
            cv2.imwrite(output_path, masked_image)
            
            # Optionnel: sauvegarder aussi le masque
            mask_path = os.path.join(output_folder, f"{name}_mask{ext}")
            cv2.imwrite(mask_path, mask)

# Utilisation
process_multiple_images("dossier_images_originales", "dossier_images_masquees")
